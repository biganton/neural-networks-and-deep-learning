# %% [markdown]
# # Autoassociation network
# AKA *Autoassociative memory*

# %%
# Check for all needed packages
import time
import typing

import IPython
import matplotlib
import mnists
import numpy

# In case of ImportError, install them to the running kernel with
# %pip install numpy matplotlib mnists
# or in the runtime container with:
# !pip install numpy matplotlib mnists
# (In case of the latter, remember to restart the kernel!)

# Tested in Python 3.14.3 with:
# numpy==2.4.3
# matplotlib==3.10.8
# mnists==0.4.1

# %%
import numpy as np
import matplotlib.pyplot as plt
import time

np.random.seed(1234)

try:
    import mkl

    mkl.set_num_threads(2)
except ImportError:
    print(
        "Intel Math Kernel Library (MKL) does not always work on every machine. "
        "Continuing without `mkl`."
    )

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]
# Out:
# Intel Math Kernel Library (MKL) does not always work on every machine. Continuing without `mkl`.

# %% [markdown]
# ### Handy utility functions

# %%
def append_ones(matrix: np.ndarray,  axis: int=1) -> np.ndarray:
    """
    Appends a column of ones to the right side of a 2D matrix.
    """
    return np.concatenate(
        (matrix, np.ones((matrix.shape[0], 1), dtype=np.float32)), axis=axis
    )


def zeros(*dims: int) -> np.ndarray:
    """
    Creates a NumPy array of zeros with the given shape.

    Args:
        *dims:  Variable number of integers defining the shape of the array.
                E.g. zeros(3, 4) creates a (3, 4) array.
    """
    return np.zeros(shape=tuple(dims), dtype=np.float32)


def ones(*dims: int) -> np.ndarray:
    """
    Creates a NumPy array of ones with the given shape.

    Args:
        *dims:  Variable number of integers defining the shape of the array.
                E.g. ones(3, 4) creates a (3, 4) array.
    """
    return np.ones(shape=tuple(dims), dtype=np.float32)


def rand(*dims: int) -> np.ndarray:
    """
    Creates a NumPy array of random values sampled from a uniform [0, 1) distribution.

    Args:
        *dims:  Variable number of integers defining the shape of the array.
                E.g. rand(3, 4) creates a (3, 4) array.
    """
    return np.random.rand(*dims).astype(np.float32)

def randn(*dims: int) -> np.ndarray:
    """
    Creates a NumPy array of random values sampled from a standard normal distribution.

    Args:
        *dims:  Variable number of integers defining the shape of the array.
                E.g. rand(3, 4) creates a (3, 4) array.
    """
    return np.random.randn(*dims).astype(np.float32)

def chunks(seq: list, size: int) -> tuple[np.ndarray]:
    """
    Splits a sequence into consecutive chunks of a given size.

    The last chunk may be smaller than `size` if the sequence length
    is not evenly divisible.

    Args:
        seq:  The input sequence (e.g. list or other sliceable) to split.
        size: The maximum number of elements in each chunk.

    Returns:
        Successive sub-sequences of length `size` (or less for the final chunk).
    """
    return tuple([seq[pos : (pos + size)] for pos in range(0, len(seq), size)])


def as_matrix(vector: np.ndarray) -> np.ndarray:
    """Reshape 1D vector to column matrix."""
    return np.reshape(vector, (-1, 1))

def arrange_tiles_img(examples: np.ndarray) -> np.ndarray:
    """
    Arrange 2D matrices as tiles

    Takes 4D `examples` tensor with dims:
        rows x cols x tile_height x tile_width
    """
    rows_count = examples.shape[0]
    cols_count = examples.shape[1]
    tile_height = examples.shape[2]
    tile_width = examples.shape[3]

    space_between_tiles = 2
    img_matrix = np.empty(
        shape=(
            rows_count * (tile_height + space_between_tiles) - space_between_tiles,
            cols_count * (tile_width + space_between_tiles) - space_between_tiles,
        )
    )
    img_matrix.fill(np.nan)

    for r in range(rows_count):
        for c in range(cols_count):
            x_0 = r * (tile_height + space_between_tiles)
            y_0 = c * (tile_width + space_between_tiles)
            img_matrix[x_0 : x_0 + tile_height, y_0 : y_0 + tile_width] = examples[r, c]

    return img_matrix


def preview_tiles(examples: np.ndarray) -> None:
    """Previews the arrange tiles"""
    img = arrange_tiles_img(examples)
    plt.matshow(img, cmap="gray", interpolation="none")
    plt.axis("off")
    plt.show()

def draw_rbm_filters(rbm: "RestrictedBoltzmannMachine") -> None:
    filters = np.reshape(np.transpose(rbm.W)[:-1, :-1], shape=(8, -1, 28, 28))
    preview_tiles(filters)

def draw_layer_filters(layer: "Layer") -> None:
    filters = np.reshape(layer.W[:-1].T, shape=(8, -1, 28, 28))
    preview_tiles(filters)

# %% [markdown]
# ### Activation functions

# %%
def sigmoid(batch: np.ndarray, stochastic: bool = False) -> np.ndarray:
    activations = 1.0 / (1.0 + np.exp(-batch))
    if stochastic:
        return activations > rand(*activations.shape).astype(np.float32)
    else:
        return activations

def sigmoid_derivative(batch: np.ndarray) -> np.ndarray:
    s = sigmoid(batch)
    return s * (1.0 - s)

# %%
# Tip: its a plain linear function with optional stochastic noise
def gaussian(batch: np.ndarray, stochastic: bool = False) -> np.ndarray:
    # TODO implement
    raise Exception("Gaussian activation function is not implemented")
    # return ???

def gaussian_derivative(batch: np.ndarray) -> np.ndarray:
    # TODO implement
    raise Exception("Derivative of the gaussian activation function is not implemented")
    # return ???

# %% [markdown]
# # MNIST dataset

# %%
from mnists import MNIST

mnist = MNIST()

PREVIEW_N_ROWS = 12
PREVIEW_N_COLS = 24
TILE_DIM = 28  # [px]


def create_mnist_digits(n_rows: int, n_cols: int, tile_dim: int) -> np.ndarray:
    shape = (n_rows, n_cols, tile_dim, tile_dim)
    return np.reshape(mnist.train_images()[: 12 * 24], shape=shape)


mnist_digits = create_mnist_digits(PREVIEW_N_ROWS, PREVIEW_N_COLS, TILE_DIM)

preview_tiles(mnist_digits)
# Out:
# Downloading https://storage.googleapis.com/cvdf-datasets/mnist/train-images-idx3-ubyte.gz to /tmp/mnists/MNIST/train-images-idx3-ubyte.gz
# Downloading https://storage.googleapis.com/cvdf-datasets/mnist/train-labels-idx1-ubyte.gz to /tmp/mnists/MNIST/train-labels-idx1-ubyte.gz
# Downloading https://storage.googleapis.com/cvdf-datasets/mnist/t10k-images-idx3-ubyte.gz to /tmp/mnists/MNIST/t10k-images-idx3-ubyte.gz
# Downloading https://storage.googleapis.com/cvdf-datasets/mnist/t10k-labels-idx1-ubyte.gz to /tmp/mnists/MNIST/t10k-labels-idx1-ubyte.gz

# %% [markdown]
# # RBM & DBN training

# %%
class RestrictedBoltzmannMachine:
    """
    A Restricted Boltzmann Machine (RBM) with a single visible and hidden layer.

    The weight matrix W has shape (visible_size + 1, hidden_size + 1), where
    the extra row and column are reserved for bias units.

    Attributes:
        visible_size:       Number of visible (input) units, excluding the bias.
        hidden_size:        Number of hidden units, excluding the bias.
        visible_act_func:   The activation function used within visible layer.
        hidden_act_func:    The activation function used within hidden layer.
        learning_rate:      Step size used during contrastive divergence updates.
        W:                  Weight matrix of shape (visible_size+1, hidden_size+1).
        momentum:           Momentum coefficient.
        l2_penalty:         Coefficent for the L2 regularization.
    """
    
    def __init__(
        self, 
        visible_size: int,
        hidden_size: int,
        visible_act_func: callable, 
        hidden_act_func: callable, 
        learning_rate: float,
        momentum: float,
        l2_penalty: float,
    ):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        
        self.visible_act_func = visible_act_func
        self.hidden_act_func = hidden_act_func
        
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.l2_penalty = l2_penalty
        
        self.reset()
    
    def reset(self) -> None:
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size+1)).astype(np.float32)
        self.W[:, -1] = 0.0  # zero hidden-bias weights
        self.W[-1, :] = 0.0  # zero visible-bias weights
        self.M = zeros(self.visible_size+1, self.hidden_size+1)

# %%
from typing import TypeAlias
DBN: TypeAlias = list[RestrictedBoltzmannMachine]

# %%
def cdk(rbm: RestrictedBoltzmannMachine, minibatch: np.ndarray, k: int = 1) -> None:
    observations_count = minibatch.shape[0]

    positive_visible = minibatch
    negative_visible = append_ones(zeros(observations_count, rbm.visible_size))

    positive_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    negative_hidden = append_ones(zeros(observations_count, rbm.hidden_size))

    z = minibatch @ rbm.W[:, :-1]
    positive_hidden[:, :-1] = rbm.hidden_act_func(z)
    negative_hidden[:, :-1] = rbm.hidden_act_func(z, stochastic=True)

    for cd_i in range(k):
        negative_visible[:, :-1] = rbm.visible_act_func(negative_hidden @ rbm.W[:-1, :].T,
                                                        stochastic=True)
        z = negative_visible @ rbm.W[:, :-1]
        if cd_i < (k - 1):
            negative_hidden[:, :-1] = rbm.hidden_act_func(z, stochastic=True)
        else:
            negative_hidden[:, :-1] = rbm.hidden_act_func(z)

    rbm.M *= rbm.momentum
    rbm.M += (rbm.learning_rate / observations_count) * positive_visible.T @ positive_hidden
    rbm.M -= (rbm.learning_rate / observations_count) * negative_visible.T @ negative_hidden

    if rbm.l2_penalty is not None:
        rbm.M[:-1, :-1] = rbm.M[:-1, :-1] - rbm.learning_rate * rbm.l2_penalty * rbm.W[:-1, :-1]

    rbm.W += rbm.M
    
def reconstruction_error(
    rbm: RestrictedBoltzmannMachine, minibatch: np.ndarray
) -> float:
    """
    Computes the mean per-sample reconstruction error on a minibatch.
    """
    observations_count = minibatch.shape[0]
    visible = zeros(observations_count, rbm.visible_size)
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
    hidden[:, :-1] = rbm.hidden_act_func(minibatch @ rbm.W[:, :-1])
    hidden[:, :-1] = (hidden[:, :-1] > rand(observations_count, rbm.hidden_size))
    
    visible = rbm.visible_act_func(hidden @ np.transpose(rbm.W[:-1, :]))
    
    error = minibatch[:, :-1] - visible
    return np.sum(np.square(error)) / observations_count

# %%
def propagate_up(
    dbn: DBN,
    layers_count: int,
    visible: np.ndarray,
) -> np.ndarray:
    """
    Forward pass through DBN layers: propagates visible units upward to the target layer.
    Appends bias term (ones) and applies sigmoid activation after matrix multiplication.
    """
    for i in range(layers_count):
        visible = append_ones(dbn[i].visible_act_func(visible @ dbn[i].W[:, :-1]))
    return visible

def propagate_down(
    dbn: DBN,
    layers_count: int,
    hidden: np.ndarray,
) -> np.ndarray:
    """
    Reconstruct data by propagating downward through the DBN.
    Appends bias term (ones) and applies sigmoid activation after matrix multiplication.
    """
    for i in reversed(range(layers_count)):
        hidden = append_ones(dbn[i].hidden_act_func(hidden @ np.transpose(dbn[i].W[:-1, :])))
    return hidden

def dbn_reconstuction_error(
    dbn: DBN,
    layer_idx: int,
    minibatch: np.ndarray,
) -> float:
    """
    Compute the reconstruction error for a selected DBN layer.

    The minibatch is first propagated upward to the chosen layer,
    then the reconstruction error is evaluated for that RBM.

    Args:
        dbn: List of pretrained RBM layers.
        layer_idx: Index of the RBM layer to evaluate.
        minibatch: Input minibatch.

    Returns:
        Reconstruction error as a scalar value.
    """
    propagated = propagate_up(dbn, layer_idx, minibatch)
    return reconstruction_error(dbn[layer_idx], propagated)



def train_dbn_layer(
    dbn: DBN,
    layer_idx: int,
    dataset: np.ndarray,
    batch_size: int,
) -> None:
    """
    Train one DBN layer using greedy layer-wise pretraining.

    The dataset is first propagated through all previously trained layers.
    Then the selected RBM layer is trained on minibatches.

    Args:
        dbn: List of RBM layers.
        layer_idx: Index of the RBM layer to train.
        dataset: Full training dataset.
        batch_size: Minibatch size.
    """

    dataset = propagate_up(dbn, layer_idx, dataset)

    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(dbn[layer_idx], batch)
        if batch_idx % round(batches_limit / 50) == 0:
            print("#", end="")

def run_dbn_training(
    dbn: DBN,
    dataset: np.ndarray,
    monitoring_set: np.ndarray,
    batch_size: int,
    epochs_count: int,
    target_momentum: float = 0.9,
) -> None:
    for layer_idx in range(len(dbn)):
        print(f"\nLearning layer {layer_idx}")

        for epoch in range(epochs_count):
            print(f"Epoch {epoch}:", end="\t")

            if epoch == 5:
                dbn[layer_idx].momentum = target_momentum

            start_time = time.time()
            train_dbn_layer(dbn, layer_idx, dataset, batch_size)
            elapsed = time.time() - start_time

            error = dbn_reconstuction_error(dbn, layer_idx, monitoring_set)
            print(f"\telapsed: {elapsed:>2.2f}s, reconstruction error: {error:>2.2f}")

# %% [markdown]
# # Autoencoder training

# %%
class Layer:
    def __init__(
        self, 
        visible_size: int,
        hidden_size: int,
        activation_fun: callable[np.ndarray],
        d_activation_fun: callable[np.ndarray],
        learning_rate: float,
        momentum: float,
        l2_penalty: float,
    ):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        
        self.activation_fun = activation_fun
        self.d_activation_fun = d_activation_fun
                
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.l2_penalty = l2_penalty
        
        self.reset()
    
    def reset(self) -> None:
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size)).astype(np.float32)
        self.W[-1, :] = 0.0 # biases
        
        self.activations = None
        self.d_activations = None
        self.deltas = None

        self.M = zeros(self.visible_size+1, self.hidden_size)

# %%
from typing import TypeAlias
MLP: TypeAlias = list[Layer]

# %%
def forward_pass(ae: MLP, batch: np.ndarray, compute_derivatives: bool) -> np.ndarray:
    visible = batch
    
    for layer_idx, layer in enumerate(ae):
        z = visible @ layer.W
        layer.activations = append_ones(layer.activation_fun(z))
        
        if compute_derivatives and (layer_idx < len(ae) - 1):
            layer.d_activations = layer.d_activation_fun(z)
            
        visible = layer.activations

    return visible[:, :-1]

def error_backpropagate(ae: MLP, batch: np.ndarray) -> None:
    observations_count = batch.shape[0]

    for layer_idx, layer in reversed(list(enumerate(ae))):
        if layer_idx > 0:
            prev_layer = ae[layer_idx - 1]
            visible = prev_layer.activations
            
            prev_layer.deltas = (layer.deltas @ layer.W[:-1, :].T) * prev_layer.d_activations
        else:
            visible = batch
        
        layer.M *= layer.momentum
        layer.M -= (layer.learning_rate / observations_count) * (visible.T @ layer.deltas)
        
        if layer.l2_penalty > 0:
            layer.M[:-1, :] = layer.M[:-1, :] - layer.learning_rate * layer.l2_penalty * layer.W[:-1, :]
        
        layer.W += layer.M

# %% [markdown]
# ### Cross entropy cost

# %% [markdown]
# Implement [cross entropy](https://en.wikipedia.org/wiki/Cross-entropy#Cross-entropy_minimization) cost for deep AE. To this end:
# * calculate the cross entropy cost between pixels in the input batch and their reconstructions,
# * sum the cross entropy cost over all pixels and all observations in the minibatch,
# * return average cost per input observation.
#
# In other words, for each sample in batch, we are trying to implement:
# $$
# H(p,q) = - \sum_m{p_{m} \log{q_m}}
# $$
# where $H(p,q)$ is the cross-entropy of the distribution $q$ relative to a distribition $p$ over a given set, where distributions $p \in \{y, 1-y\}$ and $q \in \{ \hat{y}, 1 - \hat{y} \}$ consist of $y$, which is an orignal sample from Mnist, and $\hat{y}$, which is a reconstruction.

# %%
def xentropy(batch: np.ndarray, reconstructions: np.ndarray) -> np.ndarray:
    observations_count = batch.shape[0]
    # TODO implement
    raise Exception("Cross entropy cost is not implemented")
    # return np.sum(...)

# %% [markdown]
# ### Training procedure

# %%
def train_ae(
    ae: MLP, dataset: np.ndarray, batch_size: np.ndarray
) -> None:
    batches_limit = dataset.shape[0] / batch_size
    batched_data = chunks(dataset, batch_size)
    
    for batch_idx, batch in enumerate(batched_data):
        reconstructions = forward_pass(ae, batch, True)
        
        # TODO implememnt (take inspiration from previous labs)
        # (This is Unsupervised Learning)
        raise Exception("Gradient of the cross entropy cost wrt the deep AE output is not implemented")
        # ae[-1].deltas = ???
        
        error_backpropagate(ae, batch)
        
        if batch_idx % round(batches_limit / 40) == 0: print("#", end="")

# %%
def run_ae_training(
    ae: MLP, 
    train_set: np.ndarray,
    validation_set: np.ndarray,
    batch_size: int,
    epochs_count: int,
) -> None:
    for epoch in range(epochs_count):
        print(f"Epoch {epoch + 1}:", end="\t")
        
        start_time = time.time()
        train_ae(ae, train_set, batch_size)
        elapsed = time.time() - start_time

        xe = xentropy(validation_set[:, :-1], forward_pass(ae, validation_set, False))
        print(f"\telapsed: {elapsed:>2.2f}s, cross-entropy: {xe:>2.2f}")

    print("Training finished!")

# %% [markdown]
# ###  Initializing AE with DBN weights
#
# Implement initialization of AE weights (and biases) using weights (and biases) from the DBN layers.
#
# Make sure that the AE weights (and biases) are **copies** of the DBN weights (and biases). You can use ```np.copy(...)``` function to copy the weights (simple assignment will make a view instead of a copy).

# %%
def initialize_ae_from_dbn(ae: MLP, dbn: DBN) -> None:
    assert(len(ae) == 2*len(dbn))
    
    # TODO implmement
    # TIP: do it 2 times (2nd time mirrored)
    raise Exception("Initialization of a deep AE is not implemented")

# %% [markdown]
# # Autoencoder for MNIST digits

# %%
np.random.seed(1234)

DATASET_SIZE: int = 10000  # 60000 for whole dataset
DIGIT_SIZE: int = 28

##### Train set #####

mnist_train_images = mnist.train_images().astype(np.float32) / 255.0
mnist_train_images = np.random.permutation(mnist_train_images)

mnist_train_images = np.reshape(mnist_train_images[:DATASET_SIZE],
                                shape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))
mnist_train_images = append_ones(mnist_train_images)

monitoring_set_indeces = np.random.choice(mnist_train_images.shape[0], 512, replace=False)
monitoring_set = mnist_train_images[monitoring_set_indeces]

##### Test set #####

mnist_test_images = mnist.test_images().astype(np.float32) / 255.0
mnist_test_images = np.reshape(mnist_test_images, shape=(-1, DIGIT_SIZE*DIGIT_SIZE))
mnist_test_images = append_ones(mnist_test_images)

# %%
VISIBLE_LAYER_SIZE: int = DIGIT_SIZE * DIGIT_SIZE

BATCH_SIZE: int = 128
EPOCHS_COUNT: int = 50

RBM_LEARNING_RATE: float = 0.1
AE_LEARNING_RATE: float = 0.01
AE_MOMENTUM: float = 0.9
L2_PENALTY: float = 0.0002

# %%
from IPython.core.display import HTML

def compare_results(
    ae: MLP, 
    dbn: DBN,
    train_set: np.ndarray,
    validation_set: np.ndarray,
    monitoring_set: np.ndarray,
    batch_size: int,
    epochs_count: int,
) -> None:
    for layer in ae:
        layer.reset()
    
    display(HTML('<h3>Plain AE training</h3>'))
    run_ae_training(
        ae=ae, 
        train_set=train_set, 
        validation_set=validation_set,
        batch_size=batch_size, 
        epochs_count=epochs_count
    )
    
    display(HTML('<h3>Input layer filters in the plain AE</h3>'))
    draw_layer_filters(ae[0])
    
    display(HTML('<h3>Input minibatch</h3>'))
    preview_tiles(np.reshape(validation_set[:8*24, :-1], shape=(8, 24, 28, 28)))
    
    display(HTML('<h3>Plain AE reconstructions</h3>'))
    ae_reconstructions = np.reshape(forward_pass(ae, validation_set[:8*24], False), shape=(8, 24, 28, 28))
    preview_tiles(ae_reconstructions)
    
    display(HTML('<h3>DBN training</h3>'))
    run_dbn_training(
        dbn=dbn, 
        dataset=train_set, 
        monitoring_set=monitoring_set, 
        batch_size=batch_size, 
        epochs_count=epochs_count
    )
    
    for layer in ae:
        layer.reset()
    
    initialize_ae_from_dbn(ae=ae, dbn=dbn)
    dbn_reconstructions = np.reshape(forward_pass(ae, validation_set[:8*24, :], False), shape=(8, 24, 28, 28))
    dbn_rec_cost = xentropy(
        batch=validation_set[:, :-1], 
        reconstructions=forward_pass(ae, validation_set, False)
    )
    
    display(HTML('<h3>Finetuning pretrained AE</h3>'))
    
    print("Reconstruction cost before finetuning: {0:>2.2f}\n".format(dbn_rec_cost))
    run_ae_training(
        ae=ae, 
        train_set=train_set, 
        validation_set=validation_set,
        batch_size=batch_size, 
        epochs_count=epochs_count
    )
    
    display(HTML('<h3>First layer filters in the DBN</h3>'))
    draw_rbm_filters(dbn[0])
    
    display(HTML('<h3>Input layer filters in the pretrained & finetuned AE</h3>'))
    draw_layer_filters(ae[0])
    
    display(HTML('<h3>Input minibatch</h3>'))
    preview_tiles(np.reshape(validation_set[:8*24, :-1], shape=(8, 24, 28, 28)))
    
    display(HTML('<h3>Pretrained AE reconstructions</h3>'))
    preview_tiles(dbn_reconstructions)
    
    display(HTML('<h3>Finetuned AE reconstructions</h3>'))
    ae_reconstructions = np.reshape(forward_pass(ae, validation_set[:8*24], False), shape=(8, 24, 28, 28))
    preview_tiles(ae_reconstructions)

# %% [markdown]
# ###  Autoencoder network
#
# Define the autoencoder network for MNIST digits. The network structure should be suitable for pretraining with the provided DBN.

# %%
dbn = [
    RestrictedBoltzmannMachine(VISIBLE_LAYER_SIZE, 256, sigmoid, sigmoid, RBM_LEARNING_RATE, 0.5, L2_PENALTY),
    RestrictedBoltzmannMachine(256, 128, sigmoid, sigmoid, RBM_LEARNING_RATE, 0.5, L2_PENALTY),
    RestrictedBoltzmannMachine(128, 64, sigmoid, sigmoid, RBM_LEARNING_RATE, 0.5, L2_PENALTY),
    RestrictedBoltzmannMachine(64, 10, sigmoid, gaussian, RBM_LEARNING_RATE / 10.0, 0.5, L2_PENALTY)
]

# TODO implement the AE architecture
raise Exception("AE structure is undefined!")
ae: MLP =  [ Layer(), Layer(), Layer(), ... ]

compare_results(
    ae=ae, 
    dbn=dbn,
    train_set=mnist_train_images, 
    validation_set=mnist_test_images,
    monitoring_set=monitoring_set,
    batch_size=BATCH_SIZE, 
    epochs_count=EPOCHS_COUNT,
)
# Out:
# <h3>Plain AE training</h3>
# Epoch 1:	########################################	elapsed: 1.57s, cross-entropy: 206.27
# Epoch 2:	########################################	elapsed: 3.74s, cross-entropy: 206.18
# Epoch 3:	########################################	elapsed: 3.21s, cross-entropy: 206.16
# Epoch 4:	########################################	elapsed: 3.30s, cross-entropy: 206.15
# Epoch 5:	########################################	elapsed: 4.73s, cross-entropy: 206.14
# Epoch 6:	########################################	elapsed: 3.95s, cross-entropy: 206.14
# Epoch 7:	########################################	elapsed: 1.45s, cross-entropy: 206.13
# Epoch 8:	########################################	elapsed: 1.16s, cross-entropy: 206.12
# Epoch 9:	########################################	elapsed: 0.64s, cross-entropy: 206.12
# Epoch 10:	########################################	elapsed: 1.27s, cross-entropy: 206.11
# Epoch 11:	########################################	elapsed: 3.66s, cross-entropy: 206.11
# Epoch 12:	########################################	elapsed: 0.68s, cross-entropy: 206.10
# Epoch 13:	########################################	elapsed: 3.62s, cross-entropy: 206.10
# Epoch 14:	########################################	elapsed: 1.56s, cross-entropy: 206.10
# Epoch 15:	########################################	elapsed: 0.74s, cross-entropy: 206.09
# Epoch 16:	########################################	elapsed: 0.62s, cross-entropy: 206.09
# Epoch 17:	########################################	elapsed: 6.33s, cross-entropy: 206.08
# Epoch 18:	########################################	elapsed: 2.72s, cross-entropy: 206.08
# Epoch 19:	########################################	elapsed: 0.67s, cross-entropy: 206.08
# Epoch 20:	########################################	elapsed: 1.01s, cross-entropy: 206.07
# Epoch 21:	########################################	elapsed: 2.13s, cross-entropy: 206.07
# Epoch 22:	########################################	elapsed: 4.03s, cross-entropy: 206.07
# Epoch 23:	########################################	elapsed: 0.81s, cross-entropy: 206.07
# Epoch 24:	########################################	elapsed: 1.75s, cross-entropy: 206.06
# Epoch 25:	########################################	elapsed: 0.72s, cross-entropy: 206.06
# Epoch 26:	########################################	elapsed: 0.77s, cross-entropy: 206.06
# Epoch 27:	########################################	elapsed: 0.74s, cross-entropy: 206.06
# Epoch 28:	########################################	elapsed: 0.78s, cross-entropy: 206.05
# Epoch 29:	########################################	elapsed: 0.69s, cross-entropy: 206.05
# Epoch 30:	########################################	elapsed: 0.92s, cross-entropy: 206.05
# Epoch 31:	########################################	elapsed: 0.62s, cross-entropy: 206.05
# Epoch 32:	########################################	elapsed: 0.72s, cross-entropy: 206.04
# Epoch 33:	########################################	elapsed: 0.66s, cross-entropy: 206.04
# Epoch 34:	########################################	elapsed: 0.66s, cross-entropy: 206.04
# Epoch 35:	########################################	elapsed: 0.61s, cross-entropy: 206.04
# Epoch 36:	########################################	elapsed: 0.63s, cross-entropy: 206.04
# Epoch 37:	########################################	elapsed: 1.12s, cross-entropy: 206.03
# Epoch 38:	########################################	elapsed: 1.48s, cross-entropy: 206.03
# Epoch 39:	########################################	elapsed: 0.94s, cross-entropy: 206.03
# Epoch 40:	########################################	elapsed: 0.77s, cross-entropy: 206.03
# Epoch 41:	########################################	elapsed: 0.78s, cross-entropy: 206.03
# Epoch 42:	########################################	elapsed: 0.75s, cross-entropy: 206.03
# Epoch 43:	########################################	elapsed: 0.77s, cross-entropy: 206.02
# Epoch 44:	########################################	elapsed: 0.86s, cross-entropy: 206.02
# Epoch 45:	########################################	elapsed: 0.72s, cross-entropy: 206.02
# Epoch 46:	########################################	elapsed: 0.77s, cross-entropy: 206.02
# Epoch 47:	########################################	elapsed: 0.72s, cross-entropy: 206.02
# Epoch 48:	########################################	elapsed: 0.77s, cross-entropy: 206.02
# Epoch 49:	########################################	elapsed: 0.78s, cross-entropy: 206.01
# Epoch 50:	########################################	elapsed: 0.82s, cross-entropy: 206.01
# Training finished!
# <h3>Input layer filters in the plain AE</h3>
# <h3>Input minibatch</h3>
# <h3>Plain AE reconstructions</h3>
# <h3>DBN training</h3>
# Learning layer 0
# Epoch 0:	########################################	elapsed: 0.87s, reconstruction error: 31.53
# Epoch 1:	########################################	elapsed: 0.63s, reconstruction error: 24.97
# Epoch 2:	########################################	elapsed: 0.53s, reconstruction error: 21.29
# Epoch 3:	########################################	elapsed: 0.65s, reconstruction error: 19.22
# Epoch 4:	########################################	elapsed: 0.60s, reconstruction error: 17.93
# Epoch 5:	########################################	elapsed: 0.72s, reconstruction error: 15.39
# Epoch 6:	########################################	elapsed: 0.56s, reconstruction error: 13.66
# Epoch 7:	########################################	elapsed: 0.53s, reconstruction error: 12.39
# Epoch 8:	########################################	elapsed: 0.70s, reconstruction error: 11.93
# Epoch 9:	########################################	elapsed: 0.54s, reconstruction error: 11.42
# Epoch 10:	########################################	elapsed: 0.62s, reconstruction error: 10.92
# Epoch 11:	########################################	elapsed: 0.60s, reconstruction error: 10.83
# Epoch 12:	########################################	elapsed: 0.75s, reconstruction error: 10.55
# Epoch 13:	########################################	elapsed: 0.64s, reconstruction error: 10.42
# Epoch 14:	########################################	elapsed: 0.58s, reconstruction error: 10.32
# Epoch 15:	########################################	elapsed: 0.68s, reconstruction error: 9.99
# Epoch 16:	########################################	elapsed: 0.53s, reconstruction error: 10.00
# Epoch 17:	########################################	elapsed: 0.72s, reconstruction error: 9.75
# Epoch 18:	########################################	elapsed: 0.68s, reconstruction error: 9.73
# Epoch 19:	########################################	elapsed: 0.65s, reconstruction error: 9.64
# Epoch 20:	########################################	elapsed: 1.36s, reconstruction error: 9.59
# Epoch 21:	########################################	elapsed: 1.16s, reconstruction error: 9.41
# Epoch 22:	########################################	elapsed: 0.86s, reconstruction error: 9.67
# Epoch 23:	########################################	elapsed: 1.03s, reconstruction error: 9.35
# Epoch 24:	########################################	elapsed: 0.72s, reconstruction error: 9.43
# Epoch 25:	########################################	elapsed: 0.91s, reconstruction error: 9.19
# Epoch 26:	########################################	elapsed: 0.89s, reconstruction error: 9.30
# Epoch 27:	########################################	elapsed: 0.69s, reconstruction error: 9.13
# Epoch 28:	########################################	elapsed: 0.63s, reconstruction error: 9.16
# Epoch 29:	########################################	elapsed: 0.58s, reconstruction error: 9.19
# Epoch 30:	########################################	elapsed: 0.65s, reconstruction error: 9.13
# Epoch 31:	########################################	elapsed: 0.57s, reconstruction error: 9.12
# Epoch 32:	########################################	elapsed: 0.71s, reconstruction error: 9.13
# Epoch 33:	########################################	elapsed: 0.77s, reconstruction error: 9.09
# Epoch 34:	########################################	elapsed: 0.62s, reconstruction error: 9.06
# Epoch 35:	########################################	elapsed: 0.72s, reconstruction error: 8.95
# Epoch 36:	########################################	elapsed: 0.53s, reconstruction error: 8.91
# Epoch 37:	########################################	elapsed: 0.52s, reconstruction error: 8.91
# Epoch 38:	########################################	elapsed: 0.53s, reconstruction error: 8.91
# Epoch 39:	########################################	elapsed: 0.48s, reconstruction error: 8.88
# Epoch 40:	########################################	elapsed: 0.53s, reconstruction error: 8.79
# Epoch 41:	########################################	elapsed: 0.53s, reconstruction error: 9.05
# Epoch 42:	########################################	elapsed: 0.51s, reconstruction error: 8.81
# Epoch 43:	########################################	elapsed: 0.51s, reconstruction error: 8.80
# Epoch 44:	########################################	elapsed: 1.05s, reconstruction error: 8.75
# Epoch 45:	########################################	elapsed: 0.51s, reconstruction error: 8.64
# Epoch 46:	########################################	elapsed: 0.53s, reconstruction error: 8.69
# Epoch 47:	########################################	elapsed: 0.53s, reconstruction error: 8.75
# Epoch 48:	########################################	elapsed: 0.79s, reconstruction error: 8.73
# Epoch 49:	########################################	elapsed: 0.50s, reconstruction error: 8.72
#
# Learning layer 1
# Epoch 0:	########################################	elapsed: 0.18s, reconstruction error: 20.29
# Epoch 1:	########################################	elapsed: 0.20s, reconstruction error: 15.78
# Epoch 2:	########################################	elapsed: 0.18s, reconstruction error: 13.63
# Epoch 3:	########################################	elapsed: 0.17s, reconstruction error: 12.17
# Epoch 4:	########################################	elapsed: 0.18s, reconstruction error: 11.19
# Epoch 5:	########################################	elapsed: 0.18s, reconstruction error: 9.34
# Epoch 6:	########################################	elapsed: 0.18s, reconstruction error: 8.20
# Epoch 7:	########################################	elapsed: 0.20s, reconstruction error: 7.52
# Epoch 8:	########################################	elapsed: 0.18s, reconstruction error: 7.13
# Epoch 9:	########################################	elapsed: 0.17s, reconstruction error: 6.91
# Epoch 10:	########################################	elapsed: 0.18s, reconstruction error: 6.65
# Epoch 11:	########################################	elapsed: 0.17s, reconstruction error: 6.50
# Epoch 12:	########################################	elapsed: 0.23s, reconstruction error: 6.28
# Epoch 13:	########################################	elapsed: 0.18s, reconstruction error: 6.32
# Epoch 14:	########################################	elapsed: 0.18s, reconstruction error: 6.17
# Epoch 15:	########################################	elapsed: 0.18s, reconstruction error: 6.03
# Epoch 16:	########################################	elapsed: 0.18s, reconstruction error: 5.93
# Epoch 17:	########################################	elapsed: 0.20s, reconstruction error: 5.96
# Epoch 18:	########################################	elapsed: 0.19s, reconstruction error: 5.95
# Epoch 19:	########################################	elapsed: 0.21s, reconstruction error: 5.75
# Epoch 20:	########################################	elapsed: 0.18s, reconstruction error: 5.79
# Epoch 21:	########################################	elapsed: 0.17s, reconstruction error: 5.75
# Epoch 22:	########################################	elapsed: 0.16s, reconstruction error: 5.61
# Epoch 23:	########################################	elapsed: 0.18s, reconstruction error: 5.65
# Epoch 24:	########################################	elapsed: 0.17s, reconstruction error: 5.70
# Epoch 25:	########################################	elapsed: 0.23s, reconstruction error: 5.60
# Epoch 26:	########################################	elapsed: 0.18s, reconstruction error: 5.55
# Epoch 27:	########################################	elapsed: 0.17s, reconstruction error: 5.50
# Epoch 28:	########################################	elapsed: 0.19s, reconstruction error: 5.45
# Epoch 29:	########################################	elapsed: 0.17s, reconstruction error: 5.42
# Epoch 30:	########################################	elapsed: 0.18s, reconstruction error: 5.39
# Epoch 31:	########################################	elapsed: 0.20s, reconstruction error: 5.43
# Epoch 32:	########################################	elapsed: 0.18s, reconstruction error: 5.37
# Epoch 33:	########################################	elapsed: 0.17s, reconstruction error: 5.39
# Epoch 34:	########################################	elapsed: 0.19s, reconstruction error: 5.42
# Epoch 35:	########################################	elapsed: 0.25s, reconstruction error: 5.36
# Epoch 36:	########################################	elapsed: 0.30s, reconstruction error: 5.26
# Epoch 37:	########################################	elapsed: 0.48s, reconstruction error: 5.26
# Epoch 38:	########################################	elapsed: 0.38s, reconstruction error: 5.20
# Epoch 39:	########################################	elapsed: 0.36s, reconstruction error: 5.29
# Epoch 40:	########################################	elapsed: 0.30s, reconstruction error: 5.21
# Epoch 41:	########################################	elapsed: 0.22s, reconstruction error: 5.22
# Epoch 42:	########################################	elapsed: 0.33s, reconstruction error: 5.16
# Epoch 43:	########################################	elapsed: 0.33s, reconstruction error: 5.13
# Epoch 44:	########################################	elapsed: 0.29s, reconstruction error: 5.20
# Epoch 45:	########################################	elapsed: 0.29s, reconstruction error: 5.14
# Epoch 46:	########################################	elapsed: 0.26s, reconstruction error: 5.11
# Epoch 47:	########################################	elapsed: 0.27s, reconstruction error: 5.11
# Epoch 48:	########################################	elapsed: 0.24s, reconstruction error: 5.14
# Epoch 49:	########################################	elapsed: 0.27s, reconstruction error: 5.19
#
# Learning layer 2
# Epoch 0:	########################################	elapsed: 0.23s, reconstruction error: 14.03
# Epoch 1:	########################################	elapsed: 0.21s, reconstruction error: 10.35
# Epoch 2:	########################################	elapsed: 0.14s, reconstruction error: 8.85
# Epoch 3:	########################################	elapsed: 0.15s, reconstruction error: 8.09
# Epoch 4:	########################################	elapsed: 0.12s, reconstruction error: 7.39
# Epoch 5:	########################################	elapsed: 0.11s, reconstruction error: 6.12
# Epoch 6:	########################################	elapsed: 0.11s, reconstruction error: 5.48
# Epoch 7:	########################################	elapsed: 0.12s, reconstruction error: 5.13
# Epoch 8:	########################################	elapsed: 0.13s, reconstruction error: 4.90
# Epoch 9:	########################################	elapsed: 0.13s, reconstruction error: 4.69
# Epoch 10:	########################################	elapsed: 0.15s, reconstruction error: 4.55
# Epoch 11:	########################################	elapsed: 0.12s, reconstruction error: 4.45
# Epoch 12:	########################################	elapsed: 0.10s, reconstruction error: 4.39
# Epoch 13:	########################################	elapsed: 0.14s, reconstruction error: 4.37
# Epoch 14:	########################################	elapsed: 0.18s, reconstruction error: 4.27
# Epoch 15:	########################################	elapsed: 0.19s, reconstruction error: 4.22
# Epoch 16:	########################################	elapsed: 0.17s, reconstruction error: 4.16
# Epoch 17:	########################################	elapsed: 0.11s, reconstruction error: 4.19
# Epoch 18:	########################################	elapsed: 0.15s, reconstruction error: 4.16
# Epoch 19:	########################################	elapsed: 0.14s, reconstruction error: 4.14
# Epoch 20:	########################################	elapsed: 0.12s, reconstruction error: 4.13
# Epoch 21:	########################################	elapsed: 0.16s, reconstruction error: 4.01
# Epoch 22:	########################################	elapsed: 0.12s, reconstruction error: 4.10
# Epoch 23:	########################################	elapsed: 0.14s, reconstruction error: 4.11
# Epoch 24:	########################################	elapsed: 0.19s, reconstruction error: 4.01
# Epoch 25:	########################################	elapsed: 0.14s, reconstruction error: 4.03
# Epoch 26:	########################################	elapsed: 0.29s, reconstruction error: 4.01
# Epoch 27:	########################################	elapsed: 0.29s, reconstruction error: 4.01
# Epoch 28:	########################################	elapsed: 0.31s, reconstruction error: 3.90
# Epoch 29:	########################################	elapsed: 0.28s, reconstruction error: 3.94
# Epoch 30:	########################################	elapsed: 0.14s, reconstruction error: 3.97
# Epoch 31:	########################################	elapsed: 0.12s, reconstruction error: 4.00
# Epoch 32:	########################################	elapsed: 0.13s, reconstruction error: 3.91
# Epoch 33:	########################################	elapsed: 0.13s, reconstruction error: 3.91
# Epoch 34:	########################################	elapsed: 0.11s, reconstruction error: 3.86
# Epoch 35:	########################################	elapsed: 0.13s, reconstruction error: 3.87
# Epoch 36:	########################################	elapsed: 0.11s, reconstruction error: 3.96
# Epoch 37:	########################################	elapsed: 0.13s, reconstruction error: 3.86
# Epoch 38:	########################################	elapsed: 0.12s, reconstruction error: 3.90
# Epoch 39:	########################################	elapsed: 0.12s, reconstruction error: 3.95
# Epoch 40:	########################################	elapsed: 0.12s, reconstruction error: 3.92
# Epoch 41:	########################################	elapsed: 0.11s, reconstruction error: 3.89
# Epoch 42:	########################################	elapsed: 0.12s, reconstruction error: 3.82
# Epoch 43:	########################################	elapsed: 0.11s, reconstruction error: 3.82
# Epoch 44:	########################################	elapsed: 0.12s, reconstruction error: 3.84
# Epoch 45:	########################################	elapsed: 0.16s, reconstruction error: 3.82
# Epoch 46:	########################################	elapsed: 0.13s, reconstruction error: 3.77
# Epoch 47:	########################################	elapsed: 0.14s, reconstruction error: 3.79
# Epoch 48:	########################################	elapsed: 0.11s, reconstruction error: 3.80
# Epoch 49:	########################################	elapsed: 0.15s, reconstruction error: 3.85
#
# Learning layer 3
# Epoch 0:	########################################	elapsed: 0.08s, reconstruction error: 11.70
# Epoch 1:	########################################	elapsed: 0.11s, reconstruction error: 10.04
# Epoch 2:	########################################	elapsed: 0.09s, reconstruction error: 9.18
# Epoch 3:	########################################	elapsed: 0.09s, reconstruction error: 8.76
# Epoch 4:	########################################	elapsed: 0.08s, reconstruction error: 8.50
# Epoch 5:	########################################	elapsed: 0.10s, reconstruction error: 8.30
# Epoch 6:	########################################	elapsed: 0.16s, reconstruction error: 8.71
# Epoch 7:	########################################	elapsed: 0.11s, reconstruction error: 8.93
# Epoch 8:	########################################	elapsed: 0.08s, reconstruction error: 9.08
# Epoch 9:	########################################	elapsed: 0.08s, reconstruction error: 9.20
# Epoch 10:	########################################	elapsed: 0.11s, reconstruction error: 9.33
# Epoch 11:	########################################	elapsed: 0.09s, reconstruction error: 9.45
# Epoch 12:	########################################	elapsed: 0.08s, reconstruction error: 9.51
# Epoch 13:	########################################	elapsed: 0.10s, reconstruction error: 9.62
# Epoch 14:	########################################	elapsed: 0.08s, reconstruction error: 9.65
# Epoch 15:	########################################	elapsed: 0.10s, reconstruction error: 9.68
# Epoch 16:	########################################	elapsed: 0.08s, reconstruction error: 9.68
# Epoch 17:	########################################	elapsed: 0.08s, reconstruction error: 9.76
# Epoch 18:	########################################	elapsed: 0.08s, reconstruction error: 9.78
# Epoch 19:	########################################	elapsed: 0.07s, reconstruction error: 9.82
# Epoch 20:	########################################	elapsed: 0.09s, reconstruction error: 9.81
# Epoch 21:	########################################	elapsed: 0.10s, reconstruction error: 9.84
# Epoch 22:	########################################	elapsed: 0.12s, reconstruction error: 9.87
# Epoch 23:	########################################	elapsed: 0.11s, reconstruction error: 9.89
# Epoch 24:	########################################	elapsed: 0.10s, reconstruction error: 9.92
# Epoch 25:	########################################	elapsed: 0.08s, reconstruction error: 9.93
# Epoch 26:	########################################	elapsed: 0.07s, reconstruction error: 9.95
# Epoch 27:	########################################	elapsed: 0.08s, reconstruction error: 9.96
# Epoch 28:	########################################	elapsed: 0.08s, reconstruction error: 10.02
# Epoch 29:	########################################	elapsed: 0.08s, reconstruction error: 10.01
# Epoch 30:	########################################	elapsed: 0.09s, reconstruction error: 10.03
# Epoch 31:	########################################	elapsed: 0.08s, reconstruction error: 10.03
# Epoch 32:	########################################	elapsed: 0.09s, reconstruction error: 10.04
# Epoch 33:	########################################	elapsed: 0.09s, reconstruction error: 10.06
# Epoch 34:	########################################	elapsed: 0.13s, reconstruction error: 10.06
# Epoch 35:	########################################	elapsed: 0.10s, reconstruction error: 10.13
# Epoch 36:	########################################	elapsed: 0.09s, reconstruction error: 10.12
# Epoch 37:	########################################	elapsed: 0.10s, reconstruction error: 10.13
# Epoch 38:	########################################	elapsed: 0.09s, reconstruction error: 10.15
# Epoch 39:	########################################	elapsed: 0.08s, reconstruction error: 10.15
# Epoch 40:	########################################	elapsed: 0.08s, reconstruction error: 10.13
# Epoch 41:	########################################	elapsed: 0.08s, reconstruction error: 10.18
# Epoch 42:	########################################	elapsed: 0.09s, reconstruction error: 10.18
# Epoch 43:	########################################	elapsed: 0.09s, reconstruction error: 10.19
# Epoch 44:	########################################	elapsed: 0.08s, reconstruction error: 10.17
# Epoch 45:	########################################	elapsed: 0.09s, reconstruction error: 10.17
# Epoch 46:	########################################	elapsed: 0.09s, reconstruction error: 10.18
# Epoch 47:	########################################	elapsed: 0.08s, reconstruction error: 10.18
# Epoch 48:	########################################	elapsed: 0.08s, reconstruction error: 10.18
# Epoch 49:	########################################	elapsed: 0.07s, reconstruction error: 10.18
# <h3>Finetuning pretrained AE</h3>
# Reconstruction cost before finetuning: 131.74
#
# Epoch 1:	########################################	elapsed: 1.04s, cross-entropy: 106.15
# Epoch 2:	########################################	elapsed: 0.86s, cross-entropy: 103.36
# Epoch 3:	########################################	elapsed: 0.96s, cross-entropy: 101.50
# Epoch 4:	########################################	elapsed: 1.04s, cross-entropy: 100.13
# Epoch 5:	########################################	elapsed: 1.26s, cross-entropy: 99.02
# Epoch 6:	########################################	elapsed: 2.32s, cross-entropy: 98.08
# Epoch 7:	########################################	elapsed: 2.06s, cross-entropy: 97.30
# Epoch 8:	########################################	elapsed: 1.48s, cross-entropy: 96.66
# Epoch 9:	########################################	elapsed: 1.52s, cross-entropy: 96.10
# Epoch 10:	########################################	elapsed: 1.57s, cross-entropy: 95.61
# Epoch 11:	########################################	elapsed: 0.99s, cross-entropy: 95.17
# Epoch 12:	########################################	elapsed: 0.82s, cross-entropy: 94.79
# Epoch 13:	########################################	elapsed: 0.94s, cross-entropy: 94.46
# Epoch 14:	########################################	elapsed: 0.95s, cross-entropy: 94.19
# Epoch 15:	########################################	elapsed: 1.13s, cross-entropy: 93.98
# Epoch 16:	########################################	elapsed: 1.31s, cross-entropy: 93.78
# Epoch 17:	########################################	elapsed: 1.64s, cross-entropy: 93.54
# Epoch 18:	########################################	elapsed: 1.14s, cross-entropy: 93.56
# Epoch 19:	########################################	elapsed: 1.15s, cross-entropy: 93.19
# Epoch 20:	########################################	elapsed: 1.26s, cross-entropy: 93.79
# Epoch 21:	########################################	elapsed: 1.22s, cross-entropy: 93.86
# Epoch 22:	########################################	elapsed: 1.41s, cross-entropy: 93.70
# Epoch 23:	########################################	elapsed: 1.36s, cross-entropy: 92.63
# Epoch 24:	########################################	elapsed: 2.10s, cross-entropy: 93.15
# Epoch 25:	########################################	elapsed: 1.14s, cross-entropy: 94.23
# Epoch 26:	########################################	elapsed: 2.02s, cross-entropy: 93.77
# Epoch 27:	########################################	elapsed: 0.98s, cross-entropy: 93.57
# Epoch 28:	########################################	elapsed: 0.86s, cross-entropy: 93.87
# Epoch 29:	########################################	elapsed: 0.70s, cross-entropy: 92.92
# Epoch 30:	########################################	elapsed: 0.76s, cross-entropy: 91.94
# Epoch 31:	########################################	elapsed: 0.72s, cross-entropy: 91.37
# Epoch 32:	########################################	elapsed: 0.70s, cross-entropy: 91.31
# Epoch 33:	########################################	elapsed: 1.47s, cross-entropy: 91.38
# Epoch 34:	########################################	elapsed: 1.09s, cross-entropy: 91.03
# Epoch 35:	########################################	elapsed: 1.90s, cross-entropy: 90.81
# Epoch 36:	########################################	elapsed: 1.28s, cross-entropy: 90.78
# Epoch 37:	########################################	elapsed: 1.10s, cross-entropy: 90.96
# Epoch 38:	########################################	elapsed: 0.88s, cross-entropy: 90.71
# Epoch 39:	########################################	elapsed: 0.85s, cross-entropy: 90.69
# Epoch 40:	########################################	elapsed: 0.81s, cross-entropy: 90.65
# Epoch 41:	########################################	elapsed: 0.80s, cross-entropy: 90.60
# Epoch 42:	########################################	elapsed: 0.78s, cross-entropy: 91.12
# Epoch 43:	########################################	elapsed: 0.80s, cross-entropy: 92.41
# Epoch 44:	########################################	elapsed: 0.75s, cross-entropy: 91.44
# Epoch 45:	########################################	elapsed: 0.87s, cross-entropy: 90.89
# Epoch 46:	########################################	elapsed: 0.80s, cross-entropy: 90.86
# Epoch 47:	########################################	elapsed: 0.78s, cross-entropy: 90.64
# Epoch 48:	########################################	elapsed: 0.77s, cross-entropy: 90.40
# Epoch 49:	########################################	elapsed: 0.95s, cross-entropy: 90.78
# Epoch 50:	########################################	elapsed: 0.98s, cross-entropy: 91.47
# Training finished!
# <h3>First layer filters in the DBN</h3>
# <h3>Input layer filters in the pretrained & finetuned AE</h3>
# <h3>Input minibatch</h3>
# <h3>Pretrained AE reconstructions</h3>
# <h3>Finetuned AE reconstructions</h3>

# %% [markdown]
# ## Additional materials
# * [Medium | Why do we use cross entropy in logistic regresion? A statistical view | Likelihood & log-likelihood](https://medium.com/@haythamahmed2001/why-do-we-use-cross-entropy-in-logistic-regression-a-statistical-view-4414ea95c72b)
