# %%
print("test")
# Out:
# test

# %%
import numpy as np
import matplotlib.pyplot as plt
import time
# import mkl

# mkl.set_num_threads(2)
np.random.seed(1234)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]

# %% [markdown]
# ### Handy utility functions

# %%
def append_ones(matrix, axis=1):
    return np.concatenate((matrix, np.ones((matrix.shape[0], 1), dtype=np.float32)), axis=axis)

def zeros(*dims):
    return np.zeros(shape=tuple(dims), dtype=np.float32)

def ones(*dims):
    return np.ones(shape=tuple(dims), dtype=np.float32)

def rand(*dims):
    return np.random.rand(*dims).astype(np.float32)

def randn(*dims):
    return np.random.randn(*dims).astype(np.float32)

def chunks(seq, size):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))

def as_matrix(vector):
    return np.reshape(vector, (-1, 1))

def one_hot_encode(labels):
    one_hot = zeros(labels.shape[0], np.max(labels) + 1) 
    one_hot[np.arange(labels.shape[0]), labels] = 1
    return one_hot.astype(np.float32)

def classify(mlp, batch):
    probabilities, _ = forward_pass(mlp, batch, False)
    return np.argmax(probabilities, axis=1)

def tiles(examples):
    rows_count = examples.shape[0]
    cols_count = examples.shape[1]
    tile_height = examples.shape[2]
    tile_width = examples.shape[3]
    
    space_between_tiles = 2
    img_matrix = np.empty(shape=(rows_count * (tile_height + space_between_tiles) - space_between_tiles,  
                                 cols_count * (tile_width + space_between_tiles) - space_between_tiles))
    img_matrix.fill(np.nan)

    for r in range(rows_count):
        for c in range(cols_count):
            x_0 = r * (tile_height + space_between_tiles)
            y_0 = c * (tile_width + space_between_tiles)
            ex_min = np.min(examples[r, c])
            ex_max = np.max(examples[r, c])
            img_matrix[x_0:x_0 + tile_height, y_0:y_0 + tile_width] = (examples[r, c] - ex_min) / (ex_max - ex_min)
    
    plt.matshow(img_matrix, cmap='gray', interpolation='none')
    plt.axis('off')
    plt.show()

def draw_layer_filters(layer):
    filters = np.reshape(layer.W[:-1].T, (16, -1, 28, 28))
    tiles(filters)

# %% [markdown]
# ### Activation functions

# %%
def sigmoid(batch, stochastic=False):
    activations = 1.0 / (1.0 + np.exp(-batch))
    if stochastic:
        return activations > rand(*activations.shape).astype(np.float32)
    else:
        return activations

def sigmoid_derivative(batch):
    s = sigmoid(batch)
    return s * (1.0 - s)


def softmax(batch):
    batch_shifted = batch - as_matrix(np.max(batch, axis=1))
    exp_batch = np.exp(batch_shifted)
    return exp_batch / as_matrix(np.sum(exp_batch, axis=1))
    # return ???

# %%
def relu(batch, stochastic=False):
    return np.maximum(batch, 0.0)
    # return ???

def relu_derivative(batch):
    return (batch > 0).astype(np.float32)
    # return ???

# %% [markdown]
# # MNIST dataset

# %%
from mnists import MNIST
import numpy as np

mnist = MNIST()

digits = np.reshape(
    mnist.train_images()[:12 * 24],
    (12, 24, 28, 28)
)

tiles(digits)

# %% [markdown]
# # MLP training

# %%
class Layer:
    def __init__(self, visible_size, hidden_size, activation_fun, d_activation_fun, 
                 dropout_rate, learning_rate, momentum, weight_limit):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        
        self.activation_fun = activation_fun
        self.d_activation_fun = d_activation_fun
        
        self.dropout_rate = dropout_rate
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.weight_limit = weight_limit
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size)).astype(np.float32)
        self.W[-1, :] = 0.0
        
        self.activations = None
        self.d_activations = None
        self.deltas = None
        
        self.M = zeros(self.visible_size+1, self.hidden_size)
        
    def deep_copy(self):
        copy = Layer(self.visible_size, self.hidden_size, self.activation_fun, self.d_activation_fun,
                     self.dropout_rate, self.learning_rate, self.momentum, self.weight_limit)
        copy.W = np.copy(self.W)
        copy.M = np.copy(self.M)
        return copy

# %%
def limit_weights(weights, limit):
    norms = np.linalg.norm(weights, axis=0)
    
    scale = np.ones_like(norms)
    mask = norms > limit
    scale[mask] = limit / norms[mask]
    
    return weights * scale
    # return ???

# %% [markdown]
# ### Forward pass
#
# Calculate total input to the neurons. Then calculate activations (remember to add *ones* as the last column). Store result in `layer.activations`.
#
# ##### Computing derivatives of activation function
#
# If `compute_derivatives` is set to `True`, we also need to compute the derivatives of the activation function and store them in `layer.d_activations`. We **do not** need to add *ones column* to the derivatives matrix! *Ones* are only needed in the activations matrix, where they are used to add biases to the total input of neurons in the next hidden layer.
#
# ##### Dropout
#
# If `compute_derivatives` is set to `True` and the dropout rate in the input layer is greater than 0, we need to calculate the dropout mask for the MLP input and apply it to `batch`.
#
# When calculating hidden activations in an MLP layer, check whether dropout rate in the next layer is greater then 0. If yes, then we need to apply dropout to the calculated activations (and derivatives of activations). In this case:
# * construct dropout mask for the hidden layer,
# * apply this mask to where it is needed in the hidden layer.
#
# Do **not** apply dropout to the last column in activations or input batch, as they contains fixed *ones*.

# %%
def forward_pass(mlp, batch, compute_derivatives):    
    if compute_derivatives and mlp[0].dropout_rate > 0:
        batch = np.copy(batch)
        
        dropout_mask = (
            rand(batch.shape[0], batch.shape[1] - 1) >= mlp[0].dropout_rate
        ).astype(np.float32)
        
        batch[:, :-1] *= dropout_mask
        
    visible = batch
    
    for layer_idx, layer in enumerate(mlp):
        z = visible @ layer.W
        layer.activations = append_ones(layer.activation_fun(z))
        
        if compute_derivatives and (layer_idx < len(mlp) - 1):
            layer.d_activations = layer.d_activation_fun(z)
            
            if mlp[layer_idx + 1].dropout_rate > 0:
                dropout_mask = (
                    rand(layer.activations.shape[0], layer.activations.shape[1] - 1) 
                    >= mlp[layer_idx + 1].dropout_rate
                ).astype(np.float32)
                
                layer.activations[:, :-1] *= dropout_mask
                layer.d_activations *= dropout_mask
        
        visible = layer.activations
    
    return visible[:, :-1], batch

     # return ???

# %% [markdown]
# ### Error backpropagation

# %%
def error_backpropagate(mlp, batch):
    observations_count = batch.shape[0]
    
    for layer_idx, layer in reversed(list(enumerate(mlp))):
        if layer_idx > 0:
            prev_layer = mlp[layer_idx - 1]
            visible = prev_layer.activations
            
            # Backpropagate error to the previous layer.
            # We skip the last row of W because it corresponds to bias.
            prev_layer.deltas = (
                layer.deltas @ layer.W[:-1, :].T
            ) * prev_layer.d_activations
        else:
            visible = batch
        
        # Gradient for current layer weights
        gradient = visible.T @ layer.deltas / observations_count
        
        # Momentum update
        layer.M = layer.momentum * layer.M - layer.learning_rate * gradient
        
        # Weight update
        layer.W += layer.M
        
        # Optional weight norm constraint
        if layer.weight_limit > 0.0:
            layer.W[:-1, :] = limit_weights(layer.W[:-1, :], layer.weight_limit)

# %% [markdown]
# ### Mean dropout network
#
# Implement the weight scalling for the network that approximates MLP outputs under dropout.

# %%
def mean_network(mlp):
    mlp = [layer.deep_copy() for layer in mlp]
    
    for layer in mlp:
        keep_probability = 1.0 - layer.dropout_rate
        layer.W[:-1, :] *= keep_probability
    
    return mlp

# return ???

# %% [markdown]
# ### Training procedure

# %%
def train_mlp(mlp, dataset, labels, batch_size):
    batches_limit = dataset.shape[0] / batch_size
    
    batched_data = chunks(dataset, batch_size)
    batched_labels = chunks(labels, batch_size)
    
    for batch_idx, (batch, batch_labels) in enumerate(zip(batched_data, batched_labels)):
        # Forward pass: compute activatations and derivatives of activations
        y, batch_with_dropout = forward_pass(mlp, batch, True)
        
        # mlp[-1].deltas = ??
        mlp[-1].deltas = y - batch_labels
        
        # Once softmax deltas are set, we may backpropagate errors
        error_backpropagate(mlp, batch_with_dropout)
        
        if batch_idx % round(batches_limit / 40) == 0: print("#", end="")

# %%
def run_mlp_training(mlp, train_set, train_labels, validation_set, validation_labels,
                     batch_size, epochs_count):
    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch+1),  end="\t")
        
        if epoch == 5:
            for layer in mlp:
                layer.momentum = 0.95
                layer.learning_rate = 0.15
        elif epoch == 150:
            for layer in mlp:
                layer.momentum = 0.925
                layer.learning_rate = 0.1
        elif epoch == 175:
            for layer in mlp:
                layer.momentum = 0.9
                layer.learning_rate = 0.01
                
        start_time = time.time()
        train_mlp(mlp, train_set, train_labels, batch_size)
        elapsed = time.time() - start_time
        
        test_mlp = mean_network(mlp)
        
        predictions = classify(test_mlp, validation_set)
        accuracy = 100.0 * np.sum(predictions == validation_labels) / predictions.shape[0]
        print("\telapsed: {0:>2.2f}s, accuracy: {1:>2.2f}".format(elapsed, accuracy))

    print("Training finished!")

# %% [markdown]
# # MNIST digits classification

# %%
DATASET_SIZE = 5000  # 60000 for whole dataset
DIGIT_SIZE = 28

##### Train set #####

mnist_train_images = mnist.train_images().astype(np.float32) / 255.0
mnist_train_labels = mnist.train_labels()

order = np.random.permutation(len(mnist_train_images))
mnist_train_images = mnist_train_images[order]
mnist_train_labels = mnist_train_labels[order]

mnist_train_images = np.reshape(
    mnist_train_images[:DATASET_SIZE],
    (DATASET_SIZE, DIGIT_SIZE * DIGIT_SIZE)
)

mnist_train_images = append_ones(mnist_train_images)

mnist_train_labels = mnist_train_labels[:DATASET_SIZE]
mnist_train_labels = one_hot_encode(mnist_train_labels)

monitoring_set_indeces = np.random.choice(
    mnist_train_images.shape[0],
    512,
    replace=False
)

monitoring_set = mnist_train_images[monitoring_set_indeces]

##### Test set #####

mnist_test_images = mnist.test_images().astype(np.float32) / 255.0

mnist_test_images = np.reshape(
    mnist_test_images,
    (-1, DIGIT_SIZE * DIGIT_SIZE)
)

mnist_test_images = append_ones(mnist_test_images)

mnist_test_labels = mnist.test_labels()

# %%
VISIBLE_LAYER_SIZE = DIGIT_SIZE*DIGIT_SIZE
HIDDEN_LAYER_SIZE = 1024

BATCH_SIZE = 128
EPOCHS_COUNT = 200

LEARNING_RATE = 0.03
SOFTMAX_LEARNING_RATE = 0.15
MOMENTUM = 0.5

# %%
from IPython.core.display import HTML

def evaluate(mlp, train_set, train_labels,
             validation_set, validation_labels,
             batch_size, epochs_count):
    for layer in mlp:
        layer.reset()

    display(HTML('<h3>MLP training</h3>'))
    run_mlp_training(mlp,
                     train_set, train_labels,
                     validation_set, validation_labels,
                     batch_size, epochs_count)
    
    display(HTML('<h3>Input layer filters in MLP</h3>'))
    draw_layer_filters(mlp[0])
    
    display(HTML('<h3>Largest norms of weight-vectors in MLP layers</h3>'))
    for i, layer in enumerate(mlp):
        max_norm = np.max(np.linalg.norm(layer.W[:-1, :], axis=0))
        print('\tlayer {0}: {1:.2f}'.format(i+1, max_norm))

# %% [markdown]
# ### Plain MLP (no dropout)

# %%
mlp = [
    Layer(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu_derivative, 0.0, LEARNING_RATE, MOMENTUM,
          weight_limit=2.0),
    Layer(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu_derivative, 0.0, LEARNING_RATE, MOMENTUM,
          weight_limit=2.0),
    Layer(HIDDEN_LAYER_SIZE, 10, softmax, None, 0.0, SOFTMAX_LEARNING_RATE, MOMENTUM,
          weight_limit=2.5)
]

evaluate(mlp, 
         mnist_train_images, mnist_train_labels, 
         mnist_test_images, mnist_test_labels,
         BATCH_SIZE, EPOCHS_COUNT)
# Out:
# <h3>MLP training</h3>
# Epoch 1:	########################################	elapsed: 0.32s, accuracy: 18.95
# Epoch 2:	########################################	elapsed: 0.22s, accuracy: 46.61
# Epoch 3:	########################################	elapsed: 0.21s, accuracy: 69.78
# Epoch 4:	########################################	elapsed: 0.22s, accuracy: 75.62
# Epoch 5:	########################################	elapsed: 0.20s, accuracy: 80.25
# Epoch 6:	########################################	elapsed: 0.21s, accuracy: 88.18
# Epoch 7:	########################################	elapsed: 0.24s, accuracy: 90.42
# Epoch 30:	########################################	elapsed: 0.32s, accuracy: 95.86
# Epoch 31:	########################################	elapsed: 0.32s, accuracy: 96.01
# Epoch 32:	########################################	elapsed: 0.32s, accuracy: 96.03
# Epoch 33:	########################################	elapsed: 0.31s, accuracy: 95.95
# Epoch 34:	########################################	elapsed: 0.32s, accuracy: 95.67
# Epoch 35:	########################################	elapsed: 0.32s, accuracy: 95.72
# Epoch 36:	########################################	elapsed: 0.31s, accuracy: 95.78
# Epoch 37:	########################################	elapsed: 0.32s, accuracy: 95.76
# Epoch 38:	########################################	elapsed: 0.31s, accuracy: 95.90
# Epoch 39:	########################################	elapsed: 0.31s, accuracy: 96.11
# Epoch 40:	########################################	elapsed: 0.30s, accuracy: 96.13
# Epoch 41:	########################################	elapsed: 0.31s, accuracy: 96.09
# Epoch 42:	########################################	elapsed: 0.30s, accuracy: 96.06
# Epoch 43:	########################################	elapsed: 0.30s, accuracy: 96.38
# Epoch 44:	########################################	elapsed: 0.32s, accuracy: 96.32
# Epoch 45:	########################################	elapsed: 0.33s, accuracy: 96.30
# Epoch 46:	########################################	elapsed: 0.32s, accuracy: 96.02
# Epoch 47:	########################################	elapsed: 0.35s, accuracy: 96.08
# Epoch 48:	########################################	elapsed: 0.33s, accuracy: 95.95
# Epoch 49:	########################################	elapsed: 0.34s, accuracy: 95.83
# Epoch 50:	########################################	elapsed: 0.34s, accuracy: 95.96
# Epoch 51:	########################################	elapsed: 0.32s, accuracy: 96.44
# Epoch 52:	########################################	elapsed: 0.31s, accuracy: 96.03
# Epoch 53:	########################################	elapsed: 0.31s, accuracy: 95.89
# Epoch 54:	########################################	elapsed: 0.30s, accuracy: 96.07
# Epoch 55:	########################################	elapsed: 0.29s, accuracy: 96.14
# Epoch 56:	########################################	elapsed: 0.30s, accuracy: 96.25
# Epoch 57:	########################################	elapsed: 0.29s, accuracy: 96.39
# Epoch 58:	########################################	elapsed: 0.30s, accuracy: 95.94
# Epoch 59:	########################################	elapsed: 0.30s, accuracy: 96.12
# Epoch 60:	########################################	elapsed: 0.31s, accuracy: 96.12
# Epoch 61:	########################################	elapsed: 0.30s, accuracy: 96.17
# Epoch 62:	########################################	elapsed: 0.28s, accuracy: 96.46
# Epoch 63:	########################################	elapsed: 0.28s, accuracy: 96.35
# Epoch 64:	########################################	elapsed: 0.31s, accuracy: 96.04
# Epoch 65:	########################################	elapsed: 0.31s, accuracy: 96.28
# Epoch 66:	########################################	elapsed: 0.31s, accuracy: 96.38
# Epoch 67:	########################################	elapsed: 0.29s, accuracy: 96.19
# Epoch 68:	########################################	elapsed: 0.29s, accuracy: 96.29
# Epoch 69:	########################################	elapsed: 0.30s, accuracy: 96.34
# Epoch 70:	########################################	elapsed: 0.32s, accuracy: 96.28
# Epoch 71:	########################################	elapsed: 0.30s, accuracy: 96.24
# Epoch 72:	########################################	elapsed: 0.31s, accuracy: 96.23
# Epoch 73:	########################################	elapsed: 0.34s, accuracy: 96.39
# Epoch 74:	########################################	elapsed: 0.33s, accuracy: 96.36
# Epoch 75:	########################################	elapsed: 0.43s, accuracy: 96.20
# Epoch 76:	########################################	elapsed: 0.28s, accuracy: 96.11
# Epoch 77:	########################################	elapsed: 0.28s, accuracy: 96.11
# Epoch 78:	########################################	elapsed: 0.40s, accuracy: 96.27
# Epoch 79:	########################################	elapsed: 0.31s, accuracy: 96.22
# Epoch 80:	########################################	elapsed: 0.30s, accuracy: 95.86
# Epoch 81:	########################################	elapsed: 0.31s, accuracy: 96.07
# Epoch 82:	########################################	elapsed: 0.30s, accuracy: 96.32
# Epoch 83:	########################################	elapsed: 0.31s, accuracy: 96.19
# Epoch 84:	########################################	elapsed: 0.29s, accuracy: 96.42
# Epoch 85:	########################################	elapsed: 0.29s, accuracy: 96.21
# Epoch 86:	########################################	elapsed: 0.30s, accuracy: 96.25
# Epoch 87:	########################################	elapsed: 0.31s, accuracy: 96.52
# Epoch 88:	########################################	elapsed: 0.30s, accuracy: 96.24
# Epoch 89:	########################################	elapsed: 0.30s, accuracy: 96.20
# Epoch 90:	########################################	elapsed: 0.30s, accuracy: 96.57
# Epoch 91:	########################################	elapsed: 0.29s, accuracy: 96.45
# Epoch 92:	########################################	elapsed: 0.30s, accuracy: 96.58
# Epoch 93:	########################################	elapsed: 0.29s, accuracy: 96.32
# Epoch 94:	########################################	elapsed: 0.31s, accuracy: 96.33
# Epoch 95:	########################################	elapsed: 0.30s, accuracy: 96.66
# Epoch 96:	########################################	elapsed: 0.30s, accuracy: 96.13
# Epoch 97:	########################################	elapsed: 0.30s, accuracy: 95.94
# Epoch 98:	########################################	elapsed: 0.29s, accuracy: 96.01
# Epoch 99:	########################################	elapsed: 0.29s, accuracy: 96.29
# Epoch 100:	########################################	elapsed: 0.29s, accuracy: 96.25
# Epoch 101:	########################################	elapsed: 0.34s, accuracy: 95.99
# Epoch 102:	########################################	elapsed: 0.30s, accuracy: 96.20
# Epoch 103:	########################################	elapsed: 0.30s, accuracy: 96.56
# Epoch 104:	########################################	elapsed: 0.28s, accuracy: 96.27
# Epoch 105:	########################################	elapsed: 0.30s, accuracy: 96.55
# Epoch 106:	########################################	elapsed: 0.35s, accuracy: 96.45
# Epoch 107:	########################################	elapsed: 0.30s, accuracy: 96.43
# Epoch 108:	########################################	elapsed: 0.29s, accuracy: 96.36
# Epoch 109:	########################################	elapsed: 0.29s, accuracy: 96.31
# Epoch 110:	########################################	elapsed: 0.30s, accuracy: 96.61
# Epoch 111:	########################################	elapsed: 0.29s, accuracy: 96.39
# Epoch 112:	########################################	elapsed: 0.29s, accuracy: 96.69
# Epoch 113:	########################################	elapsed: 0.30s, accuracy: 96.57
# Epoch 114:	########################################	elapsed: 0.30s, accuracy: 96.31
# Epoch 115:	########################################	elapsed: 0.28s, accuracy: 96.34
# Epoch 116:	########################################	elapsed: 0.27s, accuracy: 96.53
# Epoch 117:	########################################	elapsed: 0.30s, accuracy: 96.36
# Epoch 118:	########################################	elapsed: 0.29s, accuracy: 95.85
# Epoch 119:	########################################	elapsed: 0.28s, accuracy: 96.65
# Epoch 120:	########################################	elapsed: 0.31s, accuracy: 96.32
# Epoch 121:	########################################	elapsed: 0.32s, accuracy: 96.84
# Epoch 122:	########################################	elapsed: 0.33s, accuracy: 96.37
# Epoch 123:	########################################	elapsed: 0.30s, accuracy: 96.23
# Epoch 124:	########################################	elapsed: 0.31s, accuracy: 96.46
# Epoch 125:	########################################	elapsed: 0.32s, accuracy: 96.32
# Epoch 126:	########################################	elapsed: 0.34s, accuracy: 96.54
# Epoch 127:	########################################	elapsed: 0.30s, accuracy: 96.46
# Epoch 128:	########################################	elapsed: 0.31s, accuracy: 96.35
# Epoch 129:	########################################	elapsed: 0.30s, accuracy: 96.81
# Epoch 130:	########################################	elapsed: 0.32s, accuracy: 96.59
# Epoch 131:	########################################	elapsed: 0.34s, accuracy: 96.14
# Epoch 132:	########################################	elapsed: 0.31s, accuracy: 96.51
# Epoch 133:	########################################	elapsed: 0.32s, accuracy: 96.29
# Epoch 134:	########################################	elapsed: 0.31s, accuracy: 96.51
# Epoch 135:	########################################	elapsed: 0.30s, accuracy: 96.22
# Epoch 136:	########################################	elapsed: 0.30s, accuracy: 96.70
# Epoch 137:	########################################	elapsed: 0.32s, accuracy: 96.42
# Epoch 138:	########################################	elapsed: 0.29s, accuracy: 96.45
# Epoch 139:	########################################	elapsed: 0.25s, accuracy: 96.48
# Epoch 140:	########################################	elapsed: 0.26s, accuracy: 96.55
# Epoch 141:	########################################	elapsed: 0.27s, accuracy: 96.40
# Epoch 142:	########################################	elapsed: 0.28s, accuracy: 96.38
# Epoch 143:	########################################	elapsed: 0.26s, accuracy: 96.46
# Epoch 144:	########################################	elapsed: 0.30s, accuracy: 96.32
# Epoch 145:	########################################	elapsed: 0.33s, accuracy: 96.63
# Epoch 146:	########################################	elapsed: 0.36s, accuracy: 96.23
# Epoch 147:	########################################	elapsed: 0.34s, accuracy: 96.48
# Epoch 148:	########################################	elapsed: 0.31s, accuracy: 96.58
# Epoch 149:	########################################	elapsed: 0.33s, accuracy: 96.43
# Epoch 150:	########################################	elapsed: 0.32s, accuracy: 96.56
# Epoch 151:	########################################	elapsed: 0.27s, accuracy: 96.46
# Epoch 152:	########################################	elapsed: 0.30s, accuracy: 96.71
# Epoch 153:	########################################	elapsed: 0.31s, accuracy: 96.54
# Epoch 154:	########################################	elapsed: 0.34s, accuracy: 96.63
# Epoch 155:	########################################	elapsed: 0.30s, accuracy: 96.74
# Epoch 156:	########################################	elapsed: 0.28s, accuracy: 96.71
# Epoch 157:	########################################	elapsed: 0.31s, accuracy: 96.77
# Epoch 158:	########################################	elapsed: 0.27s, accuracy: 96.76
# Epoch 159:	########################################	elapsed: 0.31s, accuracy: 96.64
# Epoch 160:	########################################	elapsed: 0.30s, accuracy: 96.44
# Epoch 161:	########################################	elapsed: 0.29s, accuracy: 96.78
# Epoch 162:	########################################	elapsed: 0.28s, accuracy: 96.62
# Epoch 163:	########################################	elapsed: 0.27s, accuracy: 96.65
# Epoch 164:	########################################	elapsed: 0.29s, accuracy: 96.70
# Epoch 165:	########################################	elapsed: 0.30s, accuracy: 96.70
# Epoch 166:	########################################	elapsed: 0.28s, accuracy: 96.78
# Epoch 167:	########################################	elapsed: 0.30s, accuracy: 96.81
# Epoch 168:	########################################	elapsed: 0.31s, accuracy: 96.63
# Epoch 169:	########################################	elapsed: 0.31s, accuracy: 96.43
# Epoch 170:	########################################	elapsed: 0.29s, accuracy: 96.65
# Epoch 171:	########################################	elapsed: 0.29s, accuracy: 96.65
# Epoch 172:	########################################	elapsed: 0.30s, accuracy: 96.70
# Epoch 173:	########################################	elapsed: 0.27s, accuracy: 96.70
# Epoch 174:	########################################	elapsed: 0.30s, accuracy: 96.69
# Epoch 175:	########################################	elapsed: 0.29s, accuracy: 96.60
# Epoch 176:	########################################	elapsed: 0.29s, accuracy: 96.68
# Epoch 177:	########################################	elapsed: 0.30s, accuracy: 96.70
# Epoch 178:	########################################	elapsed: 0.31s, accuracy: 96.71
# Epoch 179:	########################################	elapsed: 0.30s, accuracy: 96.69
# Epoch 180:	########################################	elapsed: 0.30s, accuracy: 96.71
# Epoch 181:	########################################	elapsed: 0.30s, accuracy: 96.73
# Epoch 182:	########################################	elapsed: 0.27s, accuracy: 96.74
# Epoch 183:	########################################	elapsed: 0.28s, accuracy: 96.73
# Epoch 184:	########################################	elapsed: 0.29s, accuracy: 96.74
# Epoch 185:	########################################	elapsed: 0.30s, accuracy: 96.73
# Epoch 186:	########################################	elapsed: 0.29s, accuracy: 96.74
# Epoch 187:	########################################	elapsed: 0.29s, accuracy: 96.73
# Epoch 188:	########################################	elapsed: 0.28s, accuracy: 96.73
# Epoch 189:	########################################	elapsed: 0.30s, accuracy: 96.74
# Epoch 190:	########################################	elapsed: 0.29s, accuracy: 96.74
# Epoch 191:	########################################	elapsed: 0.29s, accuracy: 96.76
# Epoch 192:	########################################	elapsed: 0.30s, accuracy: 96.78
# Epoch 193:	########################################	elapsed: 0.27s, accuracy: 96.73
# Epoch 194:	########################################	elapsed: 0.29s, accuracy: 96.72
# Epoch 195:	########################################	elapsed: 0.28s, accuracy: 96.73
# Epoch 196:	########################################	elapsed: 0.29s, accuracy: 96.72
# Epoch 197:	########################################	elapsed: 0.29s, accuracy: 96.68
# Epoch 198:	########################################	elapsed: 0.30s, accuracy: 96.69
# Epoch 199:	########################################	elapsed: 0.29s, accuracy: 96.73
# Epoch 200:	########################################	elapsed: 0.29s, accuracy: 96.74
# Training finished!
# <h3>Input layer filters in MLP</h3>
# <h3>Largest norms of weight-vectors in MLP layers</h3>
# 	layer 1: 2.00
# 	layer 2: 2.00
# 	layer 3: 2.50
